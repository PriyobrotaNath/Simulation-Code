# %%
import random
import math
import matplotlib.pyplot as plt

# %%
"""FOR Defender"""
xd=0
yd =0
va=60
"""FOR Enemy"""
xe=10000
ye=10000
vb=50
"""FOR Distance"""
d=1000
"""FOR Time"""
t=300
delT=2

# %% [markdown]
# #Task 1

# %%
x=xe-xd
y=ye-yd
distance = math.sqrt((x**2)+(y**2))
print(distance)
 
for i in range(1,t,delT):
    if(distance<=d):
      {
          print("Defense A wins.........")
      }
    else:
      
          """FOR Defender"""
          newDefenderXposition = (xd+((x/distance)*va*delT))
          newDefenderYposition = (yd+((y/distance)*vb*delT))
          print("newDefenderXposition =",newDefenderXposition)
          print("newDefenderYposition =",newDefenderYposition)
          
          """FOR Enemy"""
          newEnemyXposition =(xe-(vb*delT))
          newEnemyYposition =ye
          print("newEnemyXposition =",newEnemyXposition)
          print("newEnemyYposition =",newEnemyYposition)
          """New Distance"""
          x1=newEnemyXposition-newDefenderXposition
          y1=newEnemyYposition-newDefenderYposition

          newDistance = math.sqrt((x1**2)+(y1**2))
          print("newDistance=",newDistance)
          distance=newDistance
          xd=newDefenderXposition
          yd=newDefenderYposition 
          xe=newEnemyXposition
          ye=newEnemyYposition

          if(distance<=d):
            print("Defense A wins.........")
# Out:
# 14142.13562373095
# newDefenderXposition = 84.8528137423857
# newDefenderYposition = 70.71067811865476
# newEnemyXposition = 9900
# newEnemyYposition = 10000
# newDistance= 13961.658236954796
# newDefenderXposition = 170.8024896070869
# newDefenderYposition = 142.33540800590572
# newEnemyXposition = 9800
# newEnemyYposition = 10000
# newDistance= 13780.239326746512
# newDefenderXposition = 257.88370579981887
# newDefenderYposition = 214.90308816651566
# newEnemyXposition = 9700
# newEnemyYposition = 10000
# newDistance= 13597.855775348324
# newDefenderXposition = 346.1329136032647
# newDefenderYposition = 288.44409466938714
# newEnemyXposition = 9600
# newEnemyYposition = 10000
# newDistance= 13414.483745379794
# newDefenderXposition = 435.58846200730244
# newDefenderYposition = 362.99038500608526
# newEnemyXposition = 9500
# newEnemyYposition = 10000
# newDistance= 13230.098671195929
# newDefenderXposition = 526.2907333828437
# newDefenderYposition = 438.57561115236956
# ...

# %%
plt.plot(xd,yd,label="Defender")
plt.plot(xe,ye,label="Enemy")
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Defender is attacking enemy")
plt.legend()
plt.plot(avg_intl_errors)
plt.show()
