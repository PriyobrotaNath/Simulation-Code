# %%
import random 
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #MidSquareMethod

# %%
a= input('Enter number:\n')

n=input('Enter Iteration number:\n')
print(" ")
print(" ")
for i in range(int(n)):
  b=int(a)
 
  x=b**2
  
  z=str(x)
  c=z.zfill(8)
  
  y=c[2:6]
  
  a=y
  d=int(a)/10000
  print("Iteration i = ",i)
  print("Zi = ",b)
  print("Zi^2 = ",x)
  print("Zi^2 Fill with 0 =",c)
  print("New Zi = ",y)
  print("Ui = ",d)
  print(" ")
  print(" ")
# Out:
# Enter number:
# 1234
# Enter Iteration number:
# 10
#
#
# Iteration i =  0
# Zi =  1234
# Zi^2 =  1522756
# Zi^2 Fill with 0 = 01522756
# New Zi =  5227
# Ui =  0.5227
#
#
# Iteration i =  1
# Zi =  5227
# Zi^2 =  27321529
# Zi^2 Fill with 0 = 27321529
# New Zi =  3215
# Ui =  0.3215
#
#
# Iteration i =  2
# Zi =  3215
# Zi^2 =  10336225
# Zi^2 Fill with 0 = 10336225
# New Zi =  3362
# Ui =  0.3362
#
#
# Iteration i =  3
# Zi =  3362
# Zi^2 =  11303044
# Zi^2 Fill with 0 = 11303044
# New Zi =  3030
# Ui =  0.303
#
#
# Iteration i =  4
# Zi =  3030
# Zi^2 =  9180900
# Zi^2 Fill with 0 = 09180900
# New Zi =  1809
# Ui =  0.1809
#
#
# Iteration i =  5
# Zi =  1809
# Zi^2 =  3272481
# Zi^2 Fill with 0 = 03272481
# New Zi =  2724
# Ui =  0.2724
#
#
# Iteration i =  6
# Zi =  2724
# Zi^2 =  7420176
# Zi^2 Fill with 0 = 07420176
# New Zi =  4201
# Ui =  0.4201
#
#
# Iteration i =  7
# Zi =  4201
# Zi^2 =  17648401
# Zi^2 Fill with 0 = 17648401
# New Zi =  6484
# Ui =  0.6484
#
#
# ...

# %% [markdown]
# #LCG

# %%
z=input("Enter the seed(Zo) value: ")
a=input("Enter the multiplier(a) value: ")
c=input("Enter the increment(c) value: ")
m=input("Enter the modulus(m) value: ")
n=input("Enter the iteration Number:")
print(" ")
print(" ")
for i in range(int(n)):

  b=int(z)
  Zi=((int(a)*b+int(c))%int(m))
  Ui=Zi/int(m)
  z=Zi

  print("Iteration i = ",i)
  print("Zo = ",b)
  print("Zi = ",Zi)
  print("Ui = ",Ui)
  print("New seed value Z(i-1) = ",z)
  print(" ")
  print(" ")
# Out:
# Enter the seed(Zo) value: 7
# Enter the multiplier(a) value: 5
# Enter the increment(c) value: 3
# Enter the modulus(m) value: 16
# Enter the iteration Number:20
#
#
# Iteration i =  0
# Zo =  7
# Zi =  6
# Ui =  0.375
# New seed value Z(i-1) =  6
#
#
# Iteration i =  1
# Zo =  6
# Zi =  1
# Ui =  0.0625
# New seed value Z(i-1) =  1
#
#
# Iteration i =  2
# Zo =  1
# Zi =  8
# Ui =  0.5
# New seed value Z(i-1) =  8
#
#
# Iteration i =  3
# Zo =  8
# Zi =  11
# Ui =  0.6875
# New seed value Z(i-1) =  11
#
#
# Iteration i =  4
# Zo =  11
# Zi =  10
# Ui =  0.625
# New seed value Z(i-1) =  10
#
#
# Iteration i =  5
# Zo =  10
# Zi =  5
# Ui =  0.3125
# New seed value Z(i-1) =  5
#
#
# Iteration i =  6
# Zo =  5
# Zi =  12
# Ui =  0.75
# New seed value Z(i-1) =  12
#
#
# Iteration i =  7
# Zo =  12
# Zi =  15
# Ui =  0.9375
# New seed value Z(i-1) =  15
#
#
# Iteration i =  8
# Zo =  15
# Zi =  14
# Ui =  0.875
# New seed value Z(i-1) =  14
#
#
# Iteration i =  9
# Zo =  14
# Zi =  9
# ...

# %% [markdown]
# #Blum Blum Shub

# %%
p=input("Enter the prime number(p) : ")
q=input("Enter the Prime number(q) : ")
xi=input("Enter the seed value(xi) : ")
w=input("Enter the Window size(w) : ")
n=input("Enter the iteratin number(n) :")
print(" ")
print(" ")


count_list=[]
bi_list=[]

for i in range(int(n)):
  print("Iteration number :",i)
  for j in range(int(w)):
    print("Sub-teration number :",j)

    a=int(p)
    b=int(q)
    c=int(xi)


    m=a*b
    e=(c**2)
    Xi=(e%m)
    binary=bin(Xi).replace("0b", "")
    xi=Xi
    count=binary.count("1")      
    if (count%2==0):
      bi=0
      bi_list.append(bi)
    else:
      bi=1
      bi_list.append(bi)
    

    
    print("m value = ",m)
    print("xi^2 = ",e)
    print("New xi = ",Xi)
    print("Decimal(Xi) to Binary = ",binary)
    print("1 count : ",count)
    print("bi = ",bi_list)
    print(" ")
    print(" ")
    
    
  decimal = int("".join(str(x) for x in bi_list), 2)
  print("Binary to decimal : ",decimal)
  Ui=decimal/(pow(2,d)-1)
  print("Ui = ",Ui)
  print(" ")
  print(" ")
# Out:
# Enter the prime number(p) : 11
# Enter the Prime number(q) : 19
# Enter the seed value(xi) : 3
# Enter the Window size(w) : 4
# Enter the iteratin number(n) :10
#
#
# Iteration number : 0
# Sub-teration number : 0
# m value =  209
# xi^2 =  9
# New xi =  9
# Decimal(Xi) to Binary =  1001
# 1 count :  2
# bi =  [0]
#
#
# Sub-teration number : 1
# m value =  209
# xi^2 =  81
# New xi =  81
# Decimal(Xi) to Binary =  1010001
# 1 count :  3
# bi =  [0, 1]
#
#
# Sub-teration number : 2
# m value =  209
# xi^2 =  6561
# New xi =  82
# Decimal(Xi) to Binary =  1010010
# 1 count :  3
# bi =  [0, 1, 1]
#
#
# Sub-teration number : 3
# m value =  209
# xi^2 =  6724
# New xi =  36
# Decimal(Xi) to Binary =  100100
# 1 count :  2
# bi =  [0, 1, 1, 0]
#
#
# Binary to decimal :  6
# Ui =  0.4
#
#
# Iteration number : 1
# Sub-teration number : 0
# m value =  209
# xi^2 =  1296
# New xi =  42
# Decimal(Xi) to Binary =  101010
# 1 count :  3
# bi =  [0, 1, 1, 0, 1]
#
#
# Sub-teration number : 1
# ...
